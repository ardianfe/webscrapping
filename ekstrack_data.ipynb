# %%
import pandas as pd

# %%
df = pd.read_pickle('hasil2020-04-27 08:17:33.915876.pkl')

# %%
df
# Out:
#                  peg_id             peg_nip                 peg_nama  \
# 0    196411271988111008  196411271988111008          RIDWAN RUSWANDA
# 1    196411271988111008  196411271988111008          RIDWAN RUSWANDA
# 2    198208072014011008  198208072014011008  ZIA MULYAWAN RAHMATULOH
# 3    198208072014011008  198208072014011008  ZIA MULYAWAN RAHMATULOH
# 4    196101131984032000  196101131984032000           SITI NURHAYATI
# ..                  ...                 ...                      ...
# 195  196411281989031008  196411281989031008                   SUROTO
# 196  196709231994032000  196709231994032000               HENDRIYATI
# 197  196111161987031008  196111161987031008      JEJE ZAINAL MUSTOPA
# 198  196111161987031008  196111161987031008      JEJE ZAINAL MUSTOPA
# 199  197112171998022016  197112171998022016  ELIS SITI JUARIAH, S.PD
#
#     satuan_kerja_nama  satuan_kerja_id    unit_kerja_nama  jabatan_jenis  \
# ...

# %%
print(list(df))
# Out:
# ['peg_id', 'peg_nip', 'peg_nama', 'satuan_kerja_nama', 'satuan_kerja_id', 'unit_kerja_nama', 'jabatan_jenis', 'nama_jabatan', 'foto', 'tipe_pegawai', 'rank_eselon', 'rank_opd', 'jumlah_opd', 'jumlah_eselon', 'zindex_opd', 'zindex_eselon', 'umur', 'riwpendidikan', 'joki', 'kompetensi', 'u_mutasi', 'u_promosi', 'u_tetap', 'n_positif', 'n_negatif', 'u_rotasi', 'u_demosi', 'atas', 'bawah', 'rekan', 'pribadi', 'nilai', 'tmt_jabatan', 'indikator', 'eselon', 'golongan', 'kolom1', 'kolom2', 'kolom3', 'kolom4', 'kolom5', 'kolom6', 'kolom7', 'kolom8', 'kolom9', 'kolom10', 'kolom11', 'kolom12', 'kolom13', 'kolom14', 'kolom15', 'kompetensi_es3_nilai', 'kompetensi_es3_rank', 'kompetensi_es3_total', 'kompetensi_es3_zscore', 'kompetensi_es4_nilai', 'kompetensi_es4_rank', 'kompetensi_es4_total', 'kompetensi_es4_zscore', 'total_pengisi', 'pengisi_bulan', 'ratarata_pengisi', 'lv1_unit_kerja_nama', 'lv2_unit_kerja_nama', 'lv3_unit_kerja_nama', 'lv4_unit_kerja_nama', 'unit_kerja_id', 'rank_opd_akhir', '
# ...

# %%
newdf = df[['peg_nip', 'peg_nama', 'unit_kerja_nama', 'nama_tugas_tambah', 'kolom2', 'kolom3']]

# %%
newdf
# Out:
#                 peg_nip                 peg_nama    unit_kerja_nama  \
# 0    196411271988111008          RIDWAN RUSWANDA      SMAN 13 GARUT
# 1    196411271988111008          RIDWAN RUSWANDA      SMAN 13 GARUT
# 2    198208072014011008  ZIA MULYAWAN RAHMATULOH  SMAN 2 PADALARANG
# 3    198208072014011008  ZIA MULYAWAN RAHMATULOH  SMAN 2 PADALARANG
# 4    196101131984032000           SITI NURHAYATI      SMAN 10 GARUT
# ..                  ...                      ...                ...
# 195  196411281989031008                   SUROTO  SMAN 1 TELAGASARI
# 196  196709231994032000               HENDRIYATI      SMAN 1 BEKASI
# 197  196111161987031008      JEJE ZAINAL MUSTOPA   SMAN 1 MANONJAYA
# 198  196111161987031008      JEJE ZAINAL MUSTOPA   SMAN 1 MANONJAYA
# 199  197112171998022016  ELIS SITI JUARIAH, S.PD      SMAN 19 GARUT
#
#                              nama_tugas_tambah       kolom2  \
# 0                 KEPALA SEKOLAH SMAN 13 GARUT  81320414526
# ...

# %%
import datetime
x = datetime.datetime.now()

# %%
newdf.to_csv('output{}.csv'.format(x))

# %%
df = pd.read_pickle('hasil2020-04-28 05:22:22.852774.pkl')

# %%
df
# Out:
#                   peg_id             peg_nip                 peg_nama  \
# 0     197112171998022016  197112171998022016  ELIS SITI JUARIAH, S.PD
# 1     197112171998022016  197112171998022016  ELIS SITI JUARIAH, S.PD
# 2     196812011995122016  196812011995122016             YAYAN KURNIA
# 3     196812011995122016  196812011995122016             YAYAN KURNIA
# 4     196212211999031008  196212211999031008    DEDEN RACHMAT SOBIRIN
# ...                  ...                 ...                      ...
# 1795  196801111994031008  196801111994031008        ASEP KAHLAN HUSEN
# 1796  196307071987031008  196307071987031008            ACENG SOLIHIN
# 1797  196307071987031008  196307071987031008            ACENG SOLIHIN
# 1798  198506292009022016  198506292009022016      NISA NURLAELA ZAMIL
# 1799  198506292009022016  198506292009022016      NISA NURLAELA ZAMIL
#
#      satuan_kerja_nama  satuan_kerja_id                unit_kerja_nama  \
# ...

# %%
newdf_2 = df[['peg_nip', 'peg_nama', 'unit_kerja_nama', 'nama_tugas_tambah', 'kolom2', 'kolom3']]

# %%
newdf_2
# Out:
#                  peg_nip                 peg_nama  \
# 0     197112171998022016  ELIS SITI JUARIAH, S.PD
# 1     197112171998022016  ELIS SITI JUARIAH, S.PD
# 2     196812011995122016             YAYAN KURNIA
# 3     196812011995122016             YAYAN KURNIA
# 4     196212211999031008    DEDEN RACHMAT SOBIRIN
# ...                  ...                      ...
# 1795  196801111994031008        ASEP KAHLAN HUSEN
# 1796  196307071987031008            ACENG SOLIHIN
# 1797  196307071987031008            ACENG SOLIHIN
# 1798  198506292009022016      NISA NURLAELA ZAMIL
# 1799  198506292009022016      NISA NURLAELA ZAMIL
#
#                     unit_kerja_nama  \
# 0                     SMAN 19 GARUT
# 1                     SMAN 19 GARUT
# 2                         SMAN TOMO
# 3                         SMAN TOMO
# 4                    SLBN WIDI ASIH
# ...                             ...
# 1795                  SMAN 3 SUBANG
# 1796  TATA USAHA SMAN 1 DAYEUHKOLOT
# ...
