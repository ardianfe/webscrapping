# %%
import pandas as pd

# %%
df = pd.read_pickle('hasil2020-04-27 08:17:33.915876.pkl')

# %%
df
# Out:
#                  peg_id             peg_nip                 peg_nama  \
# 0    196411271988111008  196411271988111008          RIDWAN RUSWANDA
# 1    196411271988111008  196411271988111008          RIDWAN RUSWANDA
# 2    198208072014011008  198208072014011008  ZIA MULYAWAN RAHMATULOH
# 3    198208072014011008  198208072014011008  ZIA MULYAWAN RAHMATULOH
# 4    196101131984032000  196101131984032000           SITI NURHAYATI
# ..                  ...                 ...                      ...
# 195  196411281989031008  196411281989031008                   SUROTO
# 196  196709231994032000  196709231994032000               HENDRIYATI
# 197  196111161987031008  196111161987031008      JEJE ZAINAL MUSTOPA
# 198  196111161987031008  196111161987031008      JEJE ZAINAL MUSTOPA
# 199  197112171998022016  197112171998022016  ELIS SITI JUARIAH, S.PD
#
#     satuan_kerja_nama  satuan_kerja_id    unit_kerja_nama  jabatan_jenis  \
# ...

# %%
print(list(df))
# Out:
# ['peg_id', 'peg_nip', 'peg_nama', 'satuan_kerja_nama', 'satuan_kerja_id', 'unit_kerja_nama', 'jabatan_jenis', 'nama_jabatan', 'foto', 'tipe_pegawai', 'rank_eselon', 'rank_opd', 'jumlah_opd', 'jumlah_eselon', 'zindex_opd', 'zindex_eselon', 'umur', 'riwpendidikan', 'joki', 'kompetensi', 'u_mutasi', 'u_promosi', 'u_tetap', 'n_positif', 'n_negatif', 'u_rotasi', 'u_demosi', 'atas', 'bawah', 'rekan', 'pribadi', 'nilai', 'tmt_jabatan', 'indikator', 'eselon', 'golongan', 'kolom1', 'kolom2', 'kolom3', 'kolom4', 'kolom5', 'kolom6', 'kolom7', 'kolom8', 'kolom9', 'kolom10', 'kolom11', 'kolom12', 'kolom13', 'kolom14', 'kolom15', 'kompetensi_es3_nilai', 'kompetensi_es3_rank', 'kompetensi_es3_total', 'kompetensi_es3_zscore', 'kompetensi_es4_nilai', 'kompetensi_es4_rank', 'kompetensi_es4_total', 'kompetensi_es4_zscore', 'total_pengisi', 'pengisi_bulan', 'ratarata_pengisi', 'lv1_unit_kerja_nama', 'lv2_unit_kerja_nama', 'lv3_unit_kerja_nama', 'lv4_unit_kerja_nama', 'unit_kerja_id', 'rank_opd_akhir', '
# ...

# %%
newdf = df[['peg_nip', 'peg_nama', 'unit_kerja_nama', 'nama_tugas_tambah', 'kolom2', 'kolom3']]

# %%
newdf
# Out:
#                peg_nip                 peg_nama  \
# 0   196411271988111008          RIDWAN RUSWANDA
# 1   196411271988111008          RIDWAN RUSWANDA
# 2   198208072014011008  ZIA MULYAWAN RAHMATULOH
# 3   198208072014011008  ZIA MULYAWAN RAHMATULOH
# 4   196101131984032000           SITI NURHAYATI
# 5   197608251999031008           ANDI YUSTIAWAN
# 6   197608251999031008           ANDI YUSTIAWAN
# 7   196605201989031008             JOKO SUTARNO
# 8   196605201989031008             JOKO SUTARNO
# 9   196801061992011008                    NENDI
# 10  197308172000031008        ZHAIRY ANDHRYANTO
# 11  197308172000031008        ZHAIRY ANDHRYANTO
# 12  196205071989031008              ANDA SUJANA
# 13  196208211983052000     IDA HAMIDAH AGUSTINI
# 14  196208211983052000     IDA HAMIDAH AGUSTINI
# 15  196702081997022016                  MUTINAH
# 16  197206201999031008               I SETIAWAN
# 17  197206201999031008               I SETIAWAN
# ...

# %%
df2 = pd.read_pickle('hasil2.pkl')

# %%
df2
# Out:
#                 peg_id             peg_nip                        peg_nama  \
# 0   196207021985122016  196207021985122016                    RENI NURAENI
# 1   196307151988031008  196307151988031008              ASEP SURYANA, S.PD
# 2   196712141994031008  196712141994031008                CHAERUDDIN SALEH
# 3   196712141994031008  196712141994031008                CHAERUDDIN SALEH
# 4   196203031987031008  196203031987031008             DADANG ARGO PURNOMO
# 5   196606121984120992  196606121984120992                   ISEP SUPRIADI
# 6   196909111992012000  196909111992012000               SANTY KURNIA DEWI
# 7   197506052000032000  197506052000032000  DEWI SUSANTI KANIAWATI, S. PD.
# 8   197506052000032000  197506052000032000  DEWI SUSANTI KANIAWATI, S. PD.
# 9   196211261987031008  196211261987031008                   YOSEP RAHARJA
# 10  196211261987031008  196211261987031008                   YOSEP RAHARJA
# ...

# %%
newdf2 = df2[['peg_nip', 'peg_nama', 'unit_kerja_nama', 'nama_tugas_tambah', 'kolom2', 'kolom3']]

# %%
newdf2
# Out:
#                peg_nip                        peg_nama  \
# 0   196207021985122016                    RENI NURAENI
# 1   196307151988031008              ASEP SURYANA, S.PD
# 2   196712141994031008                CHAERUDDIN SALEH
# 3   196712141994031008                CHAERUDDIN SALEH
# 4   196203031987031008             DADANG ARGO PURNOMO
# 5   196606121984120992                   ISEP SUPRIADI
# 6   196909111992012000               SANTY KURNIA DEWI
# 7   197506052000032000  DEWI SUSANTI KANIAWATI, S. PD.
# 8   197506052000032000  DEWI SUSANTI KANIAWATI, S. PD.
# 9   196211261987031008                   YOSEP RAHARJA
# 10  196211261987031008                   YOSEP RAHARJA
# 11  196006041988031008                       AYI MAMAN
# 12  196503171991111008                     ISE SURYADI
# 13  196903311991011008              ARIP ZAENAL HIKMAT
# 14  196208061992031008                    YADI HARYADI
# 15  196208061992031008                    YADI HARYADI
# ...

# %%
newdf.append(newdf2, ignore_index=True)
# Out:
#                peg_nip                        peg_nama  \
# 0   196411271988111008                 RIDWAN RUSWANDA
# 1   196411271988111008                 RIDWAN RUSWANDA
# 2   198208072014011008         ZIA MULYAWAN RAHMATULOH
# 3   198208072014011008         ZIA MULYAWAN RAHMATULOH
# 4   196101131984032000                  SITI NURHAYATI
# 5   197608251999031008                  ANDI YUSTIAWAN
# 6   197608251999031008                  ANDI YUSTIAWAN
# 7   196605201989031008                    JOKO SUTARNO
# 8   196605201989031008                    JOKO SUTARNO
# 9   196801061992011008                           NENDI
# 10  197308172000031008               ZHAIRY ANDHRYANTO
# 11  197308172000031008               ZHAIRY ANDHRYANTO
# 12  196205071989031008                     ANDA SUJANA
# 13  196208211983052000            IDA HAMIDAH AGUSTINI
# 14  196208211983052000            IDA HAMIDAH AGUSTINI
# 15  196702081997022016                         MUTINAH
# ...

# %%
newdf.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>peg_nip</th>\n      <th>peg_nama</th>\n      <th>unit_kerja_nama</th>\n      <th>nama_tugas_tambah</th>\n      <th>kolom2</th>\n      <th>kolom3</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>196411271988111008</td>\n      <td>RIDWAN RUSWANDA</td>\n      <td>SMAN 13 GARUT</td>\n      <td>KEPALA SEKOLAH SMAN 13 GARUT</td>\n      <td>81320414526</td>\n      <td>ridwan_ruswanda@yahoo.com</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>196411271988111008</td>\n      <td>RIDWAN RUSWANDA</td>\n      <td>SMAN 13 GARUT</td>\n      <td>KEPALA SEKOLAH SMAN 13 GARUT</td>\n      <td>81320414526</td>\n      <td>ridwan_ruswanda@yahoo.com</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>198208072014011008</td>\n      <td>ZIA MULYAWAN RAHMATULOH</td>\n      <td>SMAN 2 PADALARANG</td>\n      <td>KEPALA LABORATORIUM SMKN 1 LEUWILIANG</td>\n      
# ...

# %%
newdf
# Out:
#                peg_nip                 peg_nama  \
# 0   196411271988111008          RIDWAN RUSWANDA
# 1   196411271988111008          RIDWAN RUSWANDA
# 2   198208072014011008  ZIA MULYAWAN RAHMATULOH
# 3   198208072014011008  ZIA MULYAWAN RAHMATULOH
# 4   196101131984032000           SITI NURHAYATI
# 5   197608251999031008           ANDI YUSTIAWAN
# 6   197608251999031008           ANDI YUSTIAWAN
# 7   196605201989031008             JOKO SUTARNO
# 8   196605201989031008             JOKO SUTARNO
# 9   196801061992011008                    NENDI
# 10  197308172000031008        ZHAIRY ANDHRYANTO
# 11  197308172000031008        ZHAIRY ANDHRYANTO
# 12  196205071989031008              ANDA SUJANA
# 13  196208211983052000     IDA HAMIDAH AGUSTINI
# 14  196208211983052000     IDA HAMIDAH AGUSTINI
# 15  196702081997022016                  MUTINAH
# 16  197206201999031008               I SETIAWAN
# 17  197206201999031008               I SETIAWAN
# ...

# %%
newdf = newdf.append(newdf2, ignore_index=True)

# %%
newdf
# Out:
#                peg_nip                        peg_nama  \
# 0   196411271988111008                 RIDWAN RUSWANDA
# 1   196411271988111008                 RIDWAN RUSWANDA
# 2   198208072014011008         ZIA MULYAWAN RAHMATULOH
# 3   198208072014011008         ZIA MULYAWAN RAHMATULOH
# 4   196101131984032000                  SITI NURHAYATI
# 5   197608251999031008                  ANDI YUSTIAWAN
# 6   197608251999031008                  ANDI YUSTIAWAN
# 7   196605201989031008                    JOKO SUTARNO
# 8   196605201989031008                    JOKO SUTARNO
# 9   196801061992011008                           NENDI
# 10  197308172000031008               ZHAIRY ANDHRYANTO
# 11  197308172000031008               ZHAIRY ANDHRYANTO
# 12  196205071989031008                     ANDA SUJANA
# 13  196208211983052000            IDA HAMIDAH AGUSTINI
# 14  196208211983052000            IDA HAMIDAH AGUSTINI
# 15  196702081997022016                         MUTINAH
# ...
